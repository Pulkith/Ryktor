# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/pulkith/Desktop/Development/Ryktor/backend/app/services/projectdata/Hospitals.csv')

# %%
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')

# %%
dft = df[['NAME','ID','STATUS','POPULATION','NAICS_CODE','NAICS_DESC','VAL_METHOD','WEBSITE','STATE_ID','OWNER','TTL_STAFF','BEDS','TRAUMA','HELIPAD']]
dft
# Out:
#                                          NAME         ID STATUS  POPULATION  \
# 0                            ANDALUSIA HEALTH    1336420   OPEN          88
# 1                   ATHENS LIMESTONE HOSPITAL    1535611   OPEN          71
# 2                   ATMORE COMMUNITY HOSPITAL     136502   OPEN          51
# 3                 BAPTIST MEDICAL CENTER EAST     236124   OPEN         150
# 4                BAPTIST MEDICAL CENTER SOUTH    1736111   OPEN         432
# ...                                       ...        ...    ...         ...
# 8335        REHABILITATION HOSPITAL OF NAPLES  196785202   OPEN          50
# 8336                     SINAI-GRACE HOSPITAL  196785128   OPEN         383
# 8337               ASCENSION ST JOHN HOSPITAL  196785137   OPEN         654
# 8338          US AIR FORCE HOSPITAL-GLENDALE   196785364   OPEN        -999
# 8339  KAISER FOUNDATION HOSPITAL - SAN MARCOS  196785281   OPEN         168
#
# ...

# %%
dft['TRAUMA'].value_counts()
# Out:
# TRAUMA
# NOT AVAILABLE                                    5983
# LEVEL IV                                         1004
# LEVEL III                                         537
# LEVEL II                                          326
# LEVEL I                                           234
# TRH                                                38
# TRF                                                32
# CTH                                                28
# LEVEL I PEDIATRIC                                  27
# LEVEL V                                            18
# LEVEL I ADULT, LEVEL I PEDIATRIC                   17
# LEVEL I ADULT, LEVEL II PEDIATRIC                  17
# Level II Trauma Center                             16
# LEVEL II ADULT, LEVEL II PEDIATRIC                 10
# ATH                                                 8
# LEVEL III ADULT                                     7
# LEVEL II PEDIATRIC                                  7
# ...

# %%
# replaces all values of -999 with 0 for all columns
dft = dft.replace(-999, 0)
score = 1.0
population_mean = dft['POPULATION'].mean()
pop_score = -(dft["POPULATION"].std() - population_mean) / 5
naics_score = 0.0

if
# Out:
# Index(['X', 'Y', 'OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')
